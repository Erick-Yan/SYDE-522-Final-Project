# %%
import pandas as pd
import ast
from scipy import stats
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
import numpy as np

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## 1. Merge Garmin and Strava Activity Datasets

# %%
garmin_df = pd.read_csv("erick-garmin-activities.csv")
strava_df = pd.read_csv("max-strava-activities.csv")

# %% [markdown]
# ### 1.1 Filter for Only Runs

# %%
garmin_runs_df = garmin_df[garmin_df["Activity Type"] == "Running"]
strava_runs_df = strava_df[strava_df["type"] == "Run"]

# %% [markdown]
# ### 1.2 Extract Average GAP from Strava DF

# %%
def compute_weighted_avg_grade_adjusted_speed(splits):
    try:
        splits = ast.literal_eval(splits)
        total_weighted_speed = sum(split['average_grade_adjusted_speed'] * split['distance'] for split in splits)
        total_distance = sum(split['distance'] for split in splits)
        weighted_avg_speed = total_weighted_speed / total_distance if total_distance != 0 else 0
        return weighted_avg_speed
    except Exception:
        return None # We will decide whether we want GAP or not later on (removes ~26 runs if not).

# %%
strava_runs_df["average_grade_adjusted_speed"] = strava_runs_df["splits_metric"].apply(compute_weighted_avg_grade_adjusted_speed)

# %% [markdown]
# ### 1.3 Column Unit Conversions
# | Garmin    | Garmin Units | Strava | Strava Units |
# | --------- | ------------ | ------ | ------------ |
# | Distance | km | distance | m |
# | Avg Run Cadence | spm | average_cadence | half of garmin's value |
# | Avg Pace | min/km | average_speed | m/s |
# | Best Pace | min/km | max_speed | m/s |
# | Avg GAP | min/km | average_grade_adjusted_speed | m/s |
# | Elapsed Time | min:sec | elapsed_time | sec |
# | Moving Time | min:sec | moving_time | sec |

# %%
def pace_to_mps(pace_str):
    if pace_str == "--":
        return None
    mins, secs = map(int, pace_str.split(":"))
    minutes_per_km = mins + secs / 60
    meters_per_second = 1000 / (minutes_per_km * 60)
    return meters_per_second

# %%
def time_str_to_sec(time):
    hrs, mins, secs = map(float, time.split(":"))
    return (hrs * 3600) + (mins * 60) + secs

# %%
# Convert Garmin units to Strava units (except cadence, which we will follow Garmin's units)
garmin_runs_df_converted = garmin_runs_df.copy()
strava_runs_df_converted = strava_runs_df.copy()
garmin_runs_df_converted["Distance"] *= 1000
# strava_runs_df_converted["average_cadence"] *= 2 # Apparently Apple Watch doesn't record cadence.
garmin_runs_df_converted["Avg Pace"] = garmin_runs_df_converted["Avg Pace"].apply(pace_to_mps)
garmin_runs_df_converted["Best Pace"] = garmin_runs_df_converted["Best Pace"].apply(pace_to_mps)
garmin_runs_df_converted["Avg GAP"] = garmin_runs_df_converted["Avg GAP"].apply(pace_to_mps)
garmin_runs_df_converted["Elapsed Time"] = garmin_runs_df_converted["Elapsed Time"].apply(time_str_to_sec)
garmin_runs_df_converted["Moving Time"] = garmin_runs_df_converted["Moving Time"].apply(time_str_to_sec)

# %% [markdown]
# ### 1.4 Column Name Coversion & Merge

# %%
# Apple Watch doesn't seem to record power as well.
garmin_to_strava_cols = {
    "Distance": "distance",
    "Calories": "calories",
    "Avg HR": "average_heartrate",
    "Max HR": "max_heartrate",
    # "Avg Run Cadence": "average_cadence",
    "Avg Pace": "average_speed",
    "Best Pace": "max_speed",
    "Avg GAP": "average_grade_adjusted_speed",
    "Total Ascent": "total_elevation_gain",
    # "Avg Power": "average_watts",
    # "Max Power": "max_watts",
    "Elapsed Time": "elapsed_time",
    "Moving Time": "moving_time",
    "Min Elevation": "elev_low",
    "Max Elevation": "elev_high"
}

# %%
garmin_runs_df_converted = garmin_runs_df_converted.rename(columns=garmin_to_strava_cols)

desired_columns = list(garmin_to_strava_cols.values())
garmin_filtered_df = garmin_runs_df_converted[desired_columns]
strava_filtered_df = strava_runs_df_converted[desired_columns]

combined_df = pd.concat([garmin_filtered_df, strava_filtered_df], ignore_index=True)

# %% [markdown]
# # 2. Data Cleaning

# %%
# Dropped runs with null heartrate, grade adjusted speed, and elevation, reducing our data set by about 30 runs in total.
# figured this was better than replacing null values with averages
combined_df_null_removed = combined_df.dropna(subset=['average_heartrate', 'average_grade_adjusted_speed', 'elev_low', 'elev_high']).reset_index(drop=True)
combined_df_null_removed
# Out:
#      distance calories average_heartrate max_heartrate  average_speed  \
# 0      6510.0      351               158           175       3.311258
# 1      6180.0      317               149           171       3.322259
# 2      5040.0      269               156           170       3.267974
# 3      4930.0      259               157           169       3.378378
# 4      5510.0      297               156           171       3.194888
# ..        ...      ...               ...           ...            ...
# 384   10473.1    530.0             143.8         166.0       3.035000
# 385   10309.2    536.0             150.6         172.0       2.652000
# 386    9971.0    518.0             142.6         175.0       2.912000
# 387    1836.2     91.0             112.0         112.0       3.680000
# 388   10458.0    520.0             124.2         145.0       2.779000
#
#      max_speed  average_grade_adjusted_speed total_elevation_gain  \
# 0    10.309278                      3.311258                   37
# 1     3.968254                      3.300330                   23
# 2     3.521127                      3.257329                   21
# 3     4.716981                      3.355705                   41
# 4     4.184100                      3.154574                   27
# ..         ...                           ...                  ...
# 384   4.500000                      3.027005                130.2
# 385   5.200000                      2.737829                109.2
# 386   5.200000                      3.174127                146.1
# 387   5.300000                      3.598320                 10.6
# 388   8.800000                      2.894542                105.6
#
#      elapsed_time  moving_time elev_low elev_high
# 0          2014.0       1964.0      324       346
# 1          2005.0       1852.0      178       190
# 2          1580.0       1538.0      169       186
# 3          1492.0       1458.0      328       350
# 4          1778.0       1714.0      337       351
# ..            ...          ...      ...       ...
# 384        3847.0       3451.0    106.1     190.2
# 385        3941.0       3888.0     34.6     148.9
# 386        3458.0       3424.0    106.1     152.2
# 387         499.0        499.0    118.3     189.8
# 388        4048.0       3763.0    106.1     189.6
#
# [389 rows x 12 columns]

# %%
# Remove runs that have data that is above or below 3 z-scores of the average for its column, besides for distance and moving_time which can be highly variable
columns_to_include = [col for col in combined_df_null_removed.select_dtypes(include=['float64', 'int64']).columns if col not in ['distance', 'moving_time']]
z_scores = stats.zscore(combined_df_null_removed[columns_to_include])
z_score_threshold = 3
mask = (abs(z_scores) < z_score_threshold).all(axis=1)
combined_df_filtered = combined_df_null_removed[mask].reset_index(drop=True)

combined_df_filtered
# Out:
#      distance calories average_heartrate max_heartrate  average_speed  \
# 0      6510.0      351               158           175       3.311258
# 1      6180.0      317               149           171       3.322259
# 2      5040.0      269               156           170       3.267974
# 3      4930.0      259               157           169       3.378378
# 4      5510.0      297               156           171       3.194888
# ..        ...      ...               ...           ...            ...
# 368   10473.1    530.0             143.8         166.0       3.035000
# 369   10309.2    536.0             150.6         172.0       2.652000
# 370    9971.0    518.0             142.6         175.0       2.912000
# 371    1836.2     91.0             112.0         112.0       3.680000
# 372   10458.0    520.0             124.2         145.0       2.779000
#
#      max_speed  average_grade_adjusted_speed total_elevation_gain  \
# 0    10.309278                      3.311258                   37
# 1     3.968254                      3.300330                   23
# 2     3.521127                      3.257329                   21
# 3     4.716981                      3.355705                   41
# 4     4.184100                      3.154574                   27
# ..         ...                           ...                  ...
# 368   4.500000                      3.027005                130.2
# 369   5.200000                      2.737829                109.2
# 370   5.200000                      3.174127                146.1
# 371   5.300000                      3.598320                 10.6
# 372   8.800000                      2.894542                105.6
#
#      elapsed_time  moving_time elev_low elev_high
# 0          2014.0       1964.0      324       346
# 1          2005.0       1852.0      178       190
# 2          1580.0       1538.0      169       186
# 3          1492.0       1458.0      328       350
# 4          1778.0       1714.0      337       351
# ..            ...          ...      ...       ...
# 368        3847.0       3451.0    106.1     190.2
# 369        3941.0       3888.0     34.6     148.9
# 370        3458.0       3424.0    106.1     152.2
# 371         499.0        499.0    118.3     189.8
# 372        4048.0       3763.0    106.1     189.6
#
# [373 rows x 12 columns]

# %%
# Remove commas and spaces before converting to numeric
combined_df_filtered['elev_low'] = combined_df_filtered['elev_low'].replace({',': '', ' ': ''}, regex=True)
combined_df_filtered['elev_high'] = combined_df_filtered['elev_high'].replace({',': '', ' ': ''}, regex=True)

# Convert object columns to be numeric
combined_df_filtered['calories'] = pd.to_numeric(combined_df_filtered['calories'], errors='coerce')
combined_df_filtered['average_heartrate'] = pd.to_numeric(combined_df_filtered['average_heartrate'], errors='coerce')
combined_df_filtered['max_heartrate'] = pd.to_numeric(combined_df_filtered['max_heartrate'], errors='coerce')
combined_df_filtered['total_elevation_gain'] = pd.to_numeric(combined_df_filtered['total_elevation_gain'], errors='coerce')
combined_df_filtered['elev_low'] = pd.to_numeric(combined_df_filtered['elev_low'], errors='coerce')
combined_df_filtered['elev_high'] = pd.to_numeric(combined_df_filtered['elev_high'], errors='coerce')

# %% [markdown]
# ## 3. Feature Scaling

# %%
# Standardize data to have a mean of 0 and a standard deviation of 1
columns_to_scale = combined_df_filtered.select_dtypes(include=['float64', 'int64']).columns.difference(['calories'])
scaler = StandardScaler()
combined_df_scaled = combined_df_filtered.copy()  # Create a copy to keep the original intact
combined_df_scaled[columns_to_scale] = scaler.fit_transform(combined_df_scaled[columns_to_scale])
combined_df_scaled
# Out:
#      distance  calories  average_heartrate  max_heartrate  average_speed  \
# 0    0.624165     351.0           1.116701       0.776841       0.660822
# 1    0.446882     317.0           0.174966       0.386458       0.703884
# 2   -0.165550     269.0           0.907427       0.288862       0.491389
# 3   -0.224644     259.0           1.012064       0.191267       0.923559
# 4    0.086944     297.0           0.907427       0.386458       0.205301
# ..        ...       ...                ...            ...            ...
# 368  2.753226     530.0          -0.369148      -0.101521      -0.420569
# 369  2.665175     536.0           0.342385       0.484054      -1.919791
# 370  2.483487     518.0          -0.494713       0.776841      -0.902042
# 371 -1.886699      91.0          -3.696613      -5.371691       2.104232
# 372  2.745114     520.0          -2.420038      -2.151031      -1.422660
#
#      max_speed  average_grade_adjusted_speed  total_elevation_gain  \
# 0     3.558670                      0.473422             -0.572274
# 1    -0.876152                      0.431843             -0.943081
# 2    -1.188867                      0.268236             -0.996054
# 3    -0.352503                      0.642528             -0.466329
# 4    -0.725192                     -0.122718             -0.837136
# ..         ...                           ...                   ...
# 368  -0.504257                     -0.608085              1.896246
# 369  -0.014687                     -1.708317              1.340035
# 370  -0.014687                     -0.048326              2.317378
# 371   0.055252                      1.565614             -1.271511
# 372   2.503102                     -1.112067              1.244684
#
#      elapsed_time  moving_time  elev_low  elev_high
# 0        0.218892     0.431056  1.185317   1.095404
# 1        0.204640     0.243666 -0.017587  -0.347607
# 2       -0.468382    -0.281695 -0.091739  -0.384607
# 3       -0.607737    -0.415545  1.218273   1.132404
# 4       -0.154833     0.012775  1.292424   1.141654
# ..            ...          ...       ...        ...
# 368      3.121595     2.918991 -0.609976  -0.345757
# 369      3.270451     3.650146 -1.199069  -0.727784
# 370      2.505582     2.873817 -0.609976  -0.697259
# 371     -2.180232    -2.020070 -0.509459  -0.349457
# 372      3.439894     3.441005 -0.609976  -0.351307
#
# [373 rows x 12 columns]

# %% [markdown]
# # 4. Feature Selection

# %% [markdown]
# ## 4.1 Recursive Feature Elimination

# %%
# Split the data into features and target.
X = combined_df_scaled.drop(columns=["calories"])
y = combined_df_scaled["calories"]

# %%
# Check the range and basic stats of calories.
print(f"Calorie mean: {y.mean()}")
print(f"Calorie std: {y.std()}")
print(f"Calorie min: {y.min()}")
print(f"Calorie max: {y.max()}")
# Out:
# Calorie mean: 286.3190348525469
# Calorie std: 98.8691303309547
# Calorie min: 55.0
# Calorie max: 677.0

# %%
models = {
    "RandomForest": RandomForestRegressor(),
    "GradientBoosting": GradientBoostingRegressor(),
    "LinearRegression": LinearRegression()
}
feature_counts = [2,3,4,5,6,7,8,9,10]
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=0)
model_results = {
    "RandomForest": [],
    "GradientBoosting": [],
    "LinearRegression": []
}

for n_features in feature_counts:
    for model_name, model in models.items():
        pipeline = Pipeline(steps=[
            ('s', RFE(estimator=model, n_features_to_select=n_features)),
            ('m', model)
        ])
        
        scores = cross_val_score(pipeline, X, y, scoring='neg_root_mean_squared_error', cv=cv, n_jobs=-1)        
        model_results[model_name].append(scores)
        print(f"{model_name} with {n_features} Features: Mean RMSE {np.mean(scores)} ({np.std(scores)})")

plt.figure(figsize=(12, 6))

plt.subplot(1, 3, 1)
plt.boxplot(model_results['RandomForest'], labels=feature_counts, showmeans=True)
plt.title('RandomForest Performance')
plt.xlabel('Number of Features')
plt.ylabel('Root Mean Squared Error (RMSE)')
plt.grid(True)

plt.subplot(1, 3, 2)
plt.boxplot(model_results['GradientBoosting'], labels=feature_counts, showmeans=True)
plt.title('GradientBoosting Performance')
plt.xlabel('Number of Features')
plt.ylabel('Root Mean Squared Error (RMSE)')
plt.grid(True)

plt.subplot(1, 3, 3)
plt.boxplot(model_results['LinearRegression'], labels=feature_counts, showmeans=True)
plt.title('LinearRegression Performance')
plt.xlabel('Number of Features')
plt.ylabel('Root Mean Squared Error (RMSE)')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# RandomForest with 2 Features: Mean RMSE -15.586661469355118 (3.433857684821366)
# GradientBoosting with 2 Features: Mean RMSE -15.472090733709909 (3.5001101120330955)
# LinearRegression with 2 Features: Mean RMSE -13.58244840896327 (2.8599130846229905)
# RandomForest with 3 Features: Mean RMSE -15.241761409221937 (3.4302536273650883)
# GradientBoosting with 3 Features: Mean RMSE -15.33703675917095 (3.70954748101811)
# LinearRegression with 3 Features: Mean RMSE -13.139926413633255 (2.736223262686367)
# RandomForest with 4 Features: Mean RMSE -14.875541015230858 (3.631333475332212)
# GradientBoosting with 4 Features: Mean RMSE -14.269647445978254 (3.3311013551821644)
# LinearRegression with 4 Features: Mean RMSE -12.830669216463965 (2.4420807982308013)
# RandomForest with 5 Features: Mean RMSE -14.91018835138503 (3.330068114716246)
# GradientBoosting with 5 Features: Mean RMSE -13.921422070657579 (3.0235814695826986)
# LinearRegression with 5 Features: Mean RMSE -12.195899350798243 (2.5517020281804115)
# RandomForest with 6 Features: Mean RMSE -14.783209934724173 (3.391902678337067)
# GradientBoosting with 6 Features: Mean RMSE -14.187173345096515 (3.196563695744786)
# LinearRegression with 6 Features: Mean RMSE -12.190839843047518 (2.5100681912457246)
# RandomForest with 7 Features: Mean RMSE -14.712157249146886 (3.550078909899358)
# GradientBoosting with 7 Features: Mean RMSE -14.143719709798471 (3.10013661253269)
# LinearRegression with 7 Features: Mean RMSE -12.075297116063677 (2.460315562418481)
# RandomForest with 8 Features: Mean RMSE -14.518349286287089 (3.4931445452592644)
# GradientBoosting with 8 Features: Mean RMSE -13.897551988660725 (3.02428033725722)
# LinearRegression with 8 Features: Mean RMSE -12.131609795983838 (2.5507261751156802)
# RandomForest with 9 Features: Mean RMSE -14.601743586285682 (3.491672417304179)
# GradientBoosting with 9 Features: Mean RMSE -13.82168212826727 (3.0117670002729806)
# LinearRegression with 9 Features: Mean RMSE -12.160395637769536 (2.5703712278366195)
# RandomForest with 10 Features: Mean RMSE -14.522156732276681 (3.520073458103638)
# GradientBoosting with 10 Features: Mean RMSE -13.753683048457487 (2.941997005815179)
# LinearRegression with 10 Features: Mean RMSE -12.139110201195983 (2.574690571347097)
# /var/folders/bf/2t517plx1z30nqwl08k6xfbr0000gn/T/ipykernel_94183/2257595549.py:28: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(model_results['RandomForest'], labels=feature_counts, showmeans=True)
# /var/folders/bf/2t517plx1z30nqwl08k6xfbr0000gn/T/ipykernel_94183/2257595549.py:35: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(model_results['GradientBoosting'], labels=feature_counts, showmeans=True)
# /var/folders/bf/2t517plx1z30nqwl08k6xfbr0000gn/T/ipykernel_94183/2257595549.py:42: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(model_results['LinearRegression'], labels=feature_counts, showmeans=True)

# %%
# Use Linear Regression as estimator and select 7 features.
rfe = RFE(estimator=LinearRegression(), n_features_to_select=7)
rfe.fit(X, y)

X_columns = list(X.columns)
for i in range(len(X_columns)):
    print(f"Column: {X_columns[i]}, Selected: {rfe.support_[i]}, Rank: {rfe.ranking_[i]}")
# Out:
# Column: distance, Selected: True, Rank: 1
# Column: average_heartrate, Selected: True, Rank: 1
# Column: max_heartrate, Selected: False, Rank: 4
# Column: average_speed, Selected: True, Rank: 1
# Column: max_speed, Selected: False, Rank: 2
# Column: average_grade_adjusted_speed, Selected: False, Rank: 3
# Column: total_elevation_gain, Selected: True, Rank: 1
# Column: elapsed_time, Selected: True, Rank: 1
# Column: moving_time, Selected: True, Rank: 1
# Column: elev_low, Selected: False, Rank: 5
# Column: elev_high, Selected: True, Rank: 1

# %%
# Filter selected columns/features.
selected_columns = X.columns[rfe.support_]
combined_df_scaled_filtered = combined_df_scaled[selected_columns]
combined_df_scaled_filtered
# Out:
#      distance  average_heartrate  average_speed  total_elevation_gain  \
# 0    0.624165           1.116701       0.660822             -0.572274
# 1    0.446882           0.174966       0.703884             -0.943081
# 2   -0.165550           0.907427       0.491389             -0.996054
# 3   -0.224644           1.012064       0.923559             -0.466329
# 4    0.086944           0.907427       0.205301             -0.837136
# ..        ...                ...            ...                   ...
# 368  2.753226          -0.369148      -0.420569              1.896246
# 369  2.665175           0.342385      -1.919791              1.340035
# 370  2.483487          -0.494713      -0.902042              2.317378
# 371 -1.886699          -3.696613       2.104232             -1.271511
# 372  2.745114          -2.420038      -1.422660              1.244684
#
#      elapsed_time  moving_time  elev_high
# 0        0.218892     0.431056   1.095404
# 1        0.204640     0.243666  -0.347607
# 2       -0.468382    -0.281695  -0.384607
# 3       -0.607737    -0.415545   1.132404
# 4       -0.154833     0.012775   1.141654
# ..            ...          ...        ...
# 368      3.121595     2.918991  -0.345757
# 369      3.270451     3.650146  -0.727784
# 370      2.505582     2.873817  -0.697259
# 371     -2.180232    -2.020070  -0.349457
# 372      3.439894     3.441005  -0.351307
#
# [373 rows x 7 columns]

# %%
# Perform Regression with a variety of degrees and regularization to get the best combination
X = combined_df_scaled_filtered
Y = combined_df_scaled["calories"]

degrees = [3, 5, 8, 10, 12]

for deg in degrees:

    F = PolynomialFeatures(degree=deg).fit_transform(X)
    X_test, X_train, Y_test, Y_train = train_test_split(
        F, Y, test_size=2/3, shuffle=True,
    )

    X_validation, X_train, Y_validation, Y_train = train_test_split(
        X_train, Y_train, test_size=1/2, shuffle=True,
    )
    
    lambdas = np.exp(np.linspace(-20, 5, 50))

    training_rmse = []
    validation_rmse = []

    for lmbd in lambdas:
        reg = Ridge(alpha=lmbd)
        reg.fit(X_train, Y_train)
        predicted_y_train = reg.predict(X_train)
        predicted_y_validation = reg.predict(X_validation)

        training_rmse.append((np.sqrt(np.mean((Y_train-predicted_y_train)**2))))
        validation_rmse.append((np.sqrt(np.mean((Y_validation-predicted_y_validation)**2))))

    # Plot RMSE vs. Regularization
    plt.figure(figsize=(10, 5))
    plt.semilogx(lambdas, training_rmse, label='Training')
    plt.semilogx(lambdas, validation_rmse, label='Validation')
    plt.title(f'Regularization (λ) vs. Root Mean Squared Error (RMSE) With Degree {deg}')
    plt.xlabel('Regularization (λ)')
    plt.ylabel('Root Mean Squared Error (RMSE)')
    plt.legend()
    plt.grid(True)
    plt.show()

    best_lambda = lambdas[np.argmin(validation_rmse)]
    print(f"Degree: {deg}")
    print(f'Best regularization (λ): {best_lambda}')

    # Re-train the model for testing data
    reg = Ridge(alpha=best_lambda)
    reg.fit(X_train, Y_train)
    predicted_y_test = reg.predict(X_test)

    # Calculate test RMSE
    test_rmse = np.sqrt(np.mean((Y_test-predicted_y_test)**2))
    print(f"Testing RMSE: {test_rmse}")
# Out:
# Degree: 3
# Best regularization (λ): 4.172733883598105
# Testing RMSE: 582.6532945605019
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.76024e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=3.66787e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=8.6605e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.61948e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.21386e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=2.2161e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=2.72331e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=4.73217e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=7.65088e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.04403e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.98027e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=3.25949e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=5.31102e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=8.69118e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# Degree: 5
# Best regularization (λ): 148.4131591025766
# Testing RMSE: 93.68535598867298
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=7.22275e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=5.97998e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=7.13051e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.0676e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=2.09576e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=2.80678e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=5.66662e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.00808e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.79698e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=2.96961e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=4.95119e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=8.32704e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# Degree: 8
# Best regularization (λ): 2.061153622438558e-09
# Testing RMSE: 50534.074252986095
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# Degree: 10
# Best regularization (λ): 148.4131591025766
# Testing RMSE: 762.998881697903
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.73154e-21): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.73154e-21): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.73154e-21): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.73154e-21): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.73154e-21): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.73154e-21): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.73154e-21): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.73154e-21): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.73154e-21): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.73154e-21): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.73154e-21): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.73154e-21): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.73154e-21): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.73154e-21): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.73154e-21): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.73154e-21): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.73154e-21): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.87161e-20): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.86758e-20): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=4.08244e-20): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=2.85382e-20): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=6.38359e-20): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.99411e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=2.4693e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=3.55836e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=6.73136e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=8.28591e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.69422e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=2.15187e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=4.18934e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=6.68483e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.05464e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.83432e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=3.00558e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=4.95336e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=8.42126e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# Degree: 12
# Best regularization (λ): 148.4131591025766
# Testing RMSE: 582096886670.2375

# %%
# We found the least error occurs with a degree of 3.
# To exhaust all possibilities, let's also try degrees of 1, 2, 3, and 4.
# Perform Regression with a variety of degrees and regularization to get the best combination
X = combined_df_scaled_filtered
Y = combined_df_scaled["calories"]

degrees = [1,2,3,4]

for deg in degrees:

    F = PolynomialFeatures(degree=deg).fit_transform(X)
    X_test, X_train, Y_test, Y_train = train_test_split(
        F, Y, test_size=2/3, shuffle=True,
    )

    X_validation, X_train, Y_validation, Y_train = train_test_split(
        X_train, Y_train, test_size=1/2, shuffle=True,
    )
    
    lambdas = np.exp(np.linspace(-20, 5, 50))

    training_rmse = []
    validation_rmse = []

    for lmbd in lambdas:
        reg = Ridge(alpha=lmbd)
        reg.fit(X_train, Y_train)
        predicted_y_train = reg.predict(X_train)
        predicted_y_validation = reg.predict(X_validation)

        training_rmse.append((np.sqrt(np.mean((Y_train-predicted_y_train)**2))))
        validation_rmse.append((np.sqrt(np.mean((Y_validation-predicted_y_validation)**2))))

    # Plot RMSE vs. Regularization
    plt.figure(figsize=(10, 5))
    plt.semilogx(lambdas, training_rmse, label='Training')
    plt.semilogx(lambdas, validation_rmse, label='Validation')
    plt.title(f'Regularization (λ) vs. Root Mean Squared Error (RMSE) With Degree {deg}')
    plt.xlabel('Regularization (λ)')
    plt.ylabel('Root Mean Squared Error (RMSE)')
    plt.legend()
    plt.grid(True)
    plt.show()

    best_lambda = lambdas[np.argmin(validation_rmse)]
    print(f"Degree: {deg}")
    print(f'Best regularization (λ): {best_lambda}')

    # Re-train the model for testing data
    reg = Ridge(alpha=best_lambda)
    reg.fit(X_train, Y_train)
    predicted_y_test = reg.predict(X_test)

    # Calculate test RMSE
    test_rmse = np.sqrt(np.mean((Y_test-predicted_y_test)**2))
    print(f"Testing RMSE: {test_rmse}")
# Out:
# Degree: 1
# Best regularization (λ): 2.061153622438558e-09
# Testing RMSE: 12.87129108696542
# Degree: 2
# Best regularization (λ): 0.3254817196982518
# Testing RMSE: 19.063215742881344
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.69673e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# Degree: 3
# Best regularization (λ): 6.95023526584222
# Testing RMSE: 22.2929822625522
# Degree: 4
# Best regularization (λ): 32.117072910054866
# Testing RMSE: 1838.119641029713

# %%
# We see that the best testing RMSE is with a degree of 1. So let's focus on this:

X = combined_df_scaled_filtered
Y = combined_df_scaled["calories"]

X_test, X_train, Y_test, Y_train = train_test_split(
    X, Y, test_size=2/3, shuffle=True,
)

X_validation, X_train, Y_validation, Y_train = train_test_split(
    X_train, Y_train, test_size=1/2, shuffle=True,
)

lambdas = np.exp(np.linspace(-20,5,50))

training_rmse = []
validation_rmse = []

for lmbd in lambdas:
    reg = Ridge(alpha=lmbd)
    reg.fit(X_train, Y_train)
    predicted_y_train = reg.predict(X_train)
    predicted_y_validation = reg.predict(X_validation)
    
    training_rmse.append((np.sqrt(np.mean((Y_train-predicted_y_train)**2))))
    validation_rmse.append((np.sqrt(np.mean((Y_validation-predicted_y_validation)**2))))

plt.figure(figsize=(10, 5))
plt.semilogx(lambdas, training_rmse, label='Training')
plt.semilogx(lambdas, validation_rmse, label='Validation')
plt.title('Regularization (λ) vs. Root Mean Squared Error (RMSE)')
plt.xlabel('Regularization (λ)')
plt.ylabel('Root Mean Squared Error (RMSE)')
plt.legend()

best_lambda = lambdas[np.argmin(validation_rmse)]
print(f'Best regularization (λ): {best_lambda}')

reg = Ridge(alpha=best_lambda)
reg.fit(X_train, Y_train)
predicted_y_test = reg.predict(X_test)

testing_rmse = (np.sqrt(np.mean((Y_test-predicted_y_test)**2)))
print(f"Testing RMSE is {testing_rmse}")

coefficients = reg.coef_
feature_names = X.columns
coeff_df = pd.DataFrame({"Feature": feature_names, "Coefficient": coefficients})
print(coeff_df.sort_values(by="Coefficient", ascending=False))
# Out:
# Best regularization (λ): 2.061153622438558e-09
# Testing RMSE is 11.251570192462465
#                 Feature  Coefficient
# 0              distance    98.639957
# 5           moving_time    20.716430
# 1     average_heartrate     4.305600
# 3  total_elevation_gain     3.359648
# 6             elev_high     0.949632
# 2         average_speed    -4.292592
# 4          elapsed_time   -22.590127
