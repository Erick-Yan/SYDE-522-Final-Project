# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
import numpy as np

# %%
# Perform Regression with a variety of degrees and regularization to get the best combination
combined_df_scaled_filtered = pd.read_csv('preprocessed_data.csv')
calories = pd.read_csv('calories.csv')

X = combined_df_scaled_filtered
Y = calories["calories"]

degrees = [3, 5, 8, 10, 12]

for deg in degrees:

    F = PolynomialFeatures(degree=deg).fit_transform(X)
    X_test, X_train, Y_test, Y_train = train_test_split(
        F, Y, test_size=2/3, shuffle=True,
    )

    X_validation, X_train, Y_validation, Y_train = train_test_split(
        X_train, Y_train, test_size=1/2, shuffle=True,
    )
    
    lambdas = np.exp(np.linspace(-20, 5, 50))

    training_rmse = []
    validation_rmse = []

    for lmbd in lambdas:
        reg = Ridge(alpha=lmbd)
        reg.fit(X_train, Y_train)
        predicted_y_train = reg.predict(X_train)
        predicted_y_validation = reg.predict(X_validation)

        training_rmse.append((np.sqrt(np.mean((Y_train-predicted_y_train)**2))))
        validation_rmse.append((np.sqrt(np.mean((Y_validation-predicted_y_validation)**2))))

    # Plot RMSE vs. Regularization
    plt.figure(figsize=(10, 5))
    plt.semilogx(lambdas, training_rmse, label='Training')
    plt.semilogx(lambdas, validation_rmse, label='Validation')
    plt.title(f'Regularization (λ) vs. Root Mean Squared Error (RMSE) With Degree {deg}')
    plt.xlabel('Regularization (λ)')
    plt.ylabel('Root Mean Squared Error (RMSE)')
    plt.legend()
    plt.grid(True)
    plt.show()

    best_lambda = lambdas[np.argmin(validation_rmse)]
    print(f"Degree: {deg}")
    print(f'Best regularization (λ): {best_lambda}')

    # Re-train the model for testing data
    reg = Ridge(alpha=best_lambda)
    reg.fit(X_train, Y_train)
    predicted_y_test = reg.predict(X_test)

    # Calculate test RMSE
    test_rmse = np.sqrt(np.mean((Y_test-predicted_y_test)**2))
    print(f"Testing RMSE: {test_rmse}")
# Out:
# Degree: 3
# Best regularization (λ): 148.4131591025766
# Testing RMSE: 48.265683640878926
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=4.18927e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=7.09362e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# Degree: 5
# Best regularization (λ): 148.4131591025766
# Testing RMSE: 100.04745160780357
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.16335e-20): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=4.63885e-20): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.92337e-20): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.42905e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=3.63451e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=4.45326e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=7.31107e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.06507e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=2.08557e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=3.62937e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=6.42247e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.08741e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.90968e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=3.23835e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# Degree: 8
# Best regularization (λ): 2.061153622438558e-09
# Testing RMSE: 5705.6827833252655
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# Degree: 10
# Best regularization (λ): 148.4131591025766
# Testing RMSE: 916.0533426463428
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:255: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=9.11495e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=9.11495e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=4.33138e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=8.28695e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=6.03045e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=9.6885e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=2.77995e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=9.9493e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=8.71206e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=6.91262e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.73476e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=2.6792e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=3.64321e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=5.41016e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=7.67764e-18): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.24388e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=1.88722e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=3.0345e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=4.87364e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# Degree: 12
# Best regularization (λ): 0.11731916609425083
# Testing RMSE: 650983.9153076437
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_ridge.py:253: LinAlgWarning: Ill-conditioned matrix (rcond=3.0345e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)

# %%
# We found the least error occurs with a degree of 3.
# To exhaust all possibilities, let's also try degrees of 1, 2, 3, and 4.
# Perform Regression with a variety of degrees and regularization to get the best combination
X = combined_df_scaled_filtered
Y = calories["calories"]

degrees = [1,2,3,4]

for deg in degrees:

    F = PolynomialFeatures(degree=deg).fit_transform(X)
    X_test, X_train, Y_test, Y_train = train_test_split(
        F, Y, test_size=2/3, shuffle=True,
    )

    X_validation, X_train, Y_validation, Y_train = train_test_split(
        X_train, Y_train, test_size=1/2, shuffle=True,
    )
    
    lambdas = np.exp(np.linspace(-20, 5, 50))

    training_rmse = []
    validation_rmse = []

    for lmbd in lambdas:
        reg = Ridge(alpha=lmbd)
        reg.fit(X_train, Y_train)
        predicted_y_train = reg.predict(X_train)
        predicted_y_validation = reg.predict(X_validation)

        training_rmse.append((np.sqrt(np.mean((Y_train-predicted_y_train)**2))))
        validation_rmse.append((np.sqrt(np.mean((Y_validation-predicted_y_validation)**2))))

    # Plot RMSE vs. Regularization
    plt.figure(figsize=(10, 5))
    plt.semilogx(lambdas, training_rmse, label='Training')
    plt.semilogx(lambdas, validation_rmse, label='Validation')
    plt.title(f'Regularization (λ) vs. Root Mean Squared Error (RMSE) With Degree {deg}')
    plt.xlabel('Regularization (λ)')
    plt.ylabel('Root Mean Squared Error (RMSE)')
    plt.legend()
    plt.grid(True)
    plt.show()

    best_lambda = lambdas[np.argmin(validation_rmse)]
    print(f"Degree: {deg}")
    print(f'Best regularization (λ): {best_lambda}')

    # Re-train the model for testing data
    reg = Ridge(alpha=best_lambda)
    reg.fit(X_train, Y_train)
    predicted_y_test = reg.predict(X_test)

    # Calculate test RMSE
    test_rmse = np.sqrt(np.mean((Y_test-predicted_y_test)**2))
    print(f"Testing RMSE: {test_rmse}")
# Out:
# Degree: 1
# Best regularization (λ): 2.061153622438558e-09
# Testing RMSE: 11.577788435136311
# Degree: 2
# Best regularization (λ): 4.172733883598105
# Testing RMSE: 9.753739573457741
# Degree: 3
# Best regularization (λ): 53.49519499734037
# Testing RMSE: 36.58867663721465
# Degree: 4
# Best regularization (λ): 4.172733883598105
# Testing RMSE: 107.15049435892281

# %%
# We see that the best testing RMSE is with a degree of 2. So let's focus on this:
X = combined_df_scaled_filtered
Y = calories["calories"]

F = PolynomialFeatures(degree=2).fit_transform(X)
X_test, X_train, Y_test, Y_train = train_test_split(
    F, Y, test_size=2/3, shuffle=True,
)

X_validation, X_train, Y_validation, Y_train = train_test_split(
    X_train, Y_train, test_size=1/2, shuffle=True,
)

lambdas = np.exp(np.linspace(-20, 5, 50))

training_rmse = []
validation_rmse = []

for lmbd in lambdas:
    reg = Ridge(alpha=lmbd)
    reg.fit(X_train, Y_train)
    predicted_y_train = reg.predict(X_train)
    predicted_y_validation = reg.predict(X_validation)

    training_rmse.append((np.sqrt(np.mean((Y_train-predicted_y_train)**2))))
    validation_rmse.append((np.sqrt(np.mean((Y_validation-predicted_y_validation)**2))))

# Plot RMSE vs. Regularization
plt.figure(figsize=(10, 5))
plt.semilogx(lambdas, training_rmse, label='Training')
plt.semilogx(lambdas, validation_rmse, label='Validation')
plt.title(f'Regularization (λ) vs. Root Mean Squared Error (RMSE) With Degree {deg}')
plt.xlabel('Regularization (λ)')
plt.ylabel('Root Mean Squared Error (RMSE)')
plt.legend()
plt.grid(True)
plt.show()

best_lambda = lambdas[np.argmin(validation_rmse)]
print(f"Degree: {deg}")
print(f'Best regularization (λ): {best_lambda}')

# Re-train the model for testing data
reg = Ridge(alpha=best_lambda)
reg.fit(X_train, Y_train)
predicted_y_test = reg.predict(X_test)

# Calculate test RMSE
test_rmse = np.sqrt(np.mean((Y_test-predicted_y_test)**2))
print(f"Testing RMSE: {test_rmse}")
# Out:
# Degree: 4
# Best regularization (λ): 0.9029926940720318
# Testing RMSE: 9.386586014129481
